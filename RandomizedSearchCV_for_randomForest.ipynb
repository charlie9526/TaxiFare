# %% [markdown]
# <a href="https://colab.research.google.com/github/charlie9526/TaxiFare/blob/master/RandomizedSearchCV_for_randomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Inports and Mounting

# %%
from google.colab import drive 
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/Colab\ Notebooks/FAIR_TAXI

# {'esti__bootstrap': True,
#  'esti__max_depth': 74,
#  'esti__max_features': 'sqrt',
#  'esti__min_samples_leaf': 4,
#  'esti__min_samples_split': 5,
#  'esti__n_estimators': 673}


# dradient boost
# 'esti__max_depth': 10,
#  'esti__max_features': 'sqrt',
#  'esti__min_samples_leaf': 1,
#  'esti__min_samples_split': 20,
#  'esti__n_estimators': 768

# xgb
# {'esti__bootstrap': True,
#  'esti__max_depth': 52,
#  'esti__max_features': 'sqrt',
#  'esti__min_samples_leaf': 4,
#  'esti__min_samples_split': 5,
#  'esti__n_estimators': 1147}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from datetime import datetime
import random
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True)              #data visualization library based on matplotlib
import numpy as np                  #support library for amtrices etc.
from scipy.stats import norm   
import warnings
warnings.filterwarnings('ignore')   #manage warnings
# %matplotlib inline                  
#magic function in ipynb. ploting the graphs inline after the code
from math import sin, cos, sqrt, atan2, radians

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC,LinearSVC
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn import metrics
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder,LabelBinarizer
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.multioutput import MultiOutputClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
trip_id  = test_df['tripid']

# %% [markdown]
# ## Definitions

# %%
#elts write a lambda function
def get_duration(x):
  if x['pickup_time']==None or x['drop_time']==None:
    return None
  
  try :
    if int(x['pickup_time'].split("/")[1])>12 or int(x['drop_time'].split("/")[1])>12:
      gap = datetime.strptime(x['pickup_time'],"%m/%d/%Y %H:%M")-datetime.strptime(x['drop_time'],"%m/%d/%Y %H:%M")
    else:
      if int(x['pickup_time'].split("/")[1]) != int(x['drop_time'].split("/")[1]):
        gap = datetime.strptime(x['pickup_time'],"%m/%d/%Y %H:%M")-datetime.strptime(x['drop_time'],"%m/%d/%Y %H:%M")
      else:
        gap = datetime.strptime(x['pickup_time'],"%d/%m/%Y %H:%M")-datetime.strptime(x['drop_time'],"%d/%m/%Y %H:%M")
    # print (gap.total_seconds()/3600,x['pickup_time'] ,x['drop_time'])
  except :
    # print(int(x['pickup_time'].split("/")[0])>12 or int(x['drop_time'].split("/")[0])>12)
    return None
  # print(abs(gap.total_seconds()/3600), x['drop_time'],x['pickup_time'])
  disti =  abs(gap.total_seconds())
  if x['duration']>0:
    return x['duration']
  else:
    return disti

class MakeTripDurationFeature(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X['time_gap'] = X.apply(lambda x:get_duration(x), axis=1)
        X = X.drop(labels=['pickup_time','drop_time'],axis=1)
        return X

# Change the label of binary values
class MakeTripDurationFeature(BaseEstimator, TransformerMixin):
    def fit(self, X, y):
        y = y.apply(lambda x:get_binary(x))
        # print (y);
        return self
    def transform(self,X):
        return X

# debugerr 
class debugerr(BaseEstimator, TransformerMixin):
    def fit(self, X, y):
        print (pd.DataFrame(X));
        return self
    def transform(self,X):
        return X

# lambda function for change label
def get_binary(x):
  if x==None:
    return 0
  if x == "correct":
    # print (x);
    return 1
  else:
    return 0

# set distance column
class set_distance(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
      return self

    def transform(self, X):
      X['distance'] = X.apply(lambda x:get_distance(x), axis=1)
      # print(X)
      # X = X.drop(labels=['pick_lat','pick_lon','drop_lat','drop_lon'],axis=1)
      return X
# lambda column get distance
def get_distance(x):
  R = 6373.0
  lat1 = radians(float(x['drop_lat']))
  lon1 = radians(float(x['drop_lon']))
  lat2 = radians(float(x['pick_lat']))
  lon2 = radians(float(x['pick_lon']))

  dlon = lon2 - lon1
  dlat = lat2 - lat1

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  return distance

# remove columns
class remove_colums_unwanted(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
      return self

    def transform(self, X):
      X = X.drop(labels=['pick_lat','pick_lon','drop_lat','drop_lon'],axis=1)
      return X


def encoding_label(label):
  if(label=='correct'):
    return 1
  else:
    return 0

def get_hour_value(x,date_time_column_name):
  if x[date_time_column_name]==None:
    return None
  return datetime.strptime(x[date_time_column_name],"%m/%d/%Y %H:%M").hour

################### Here we have to add fare_per_hour column
################### write a lambda function

def get_fare_per_min(x):
  if x["fare"]>=0 and x["duration"]>0:
    minutes = x["duration"]/60.0
    val = x['fare']/minutes
    return val
  if x["duration"]==0:
    return 0
  return None

########### This is for getting fare per distance 
########### Lambda function
def get_fare_per_distance(x):
  if x['distance']==0:
    return 0
  if x['meter_waiting_fare']>0:
    return float(x['fare']-x['meter_waiting_fare'])/x['distance']
  else:
    return float(x['fare'])/x['distance']

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# check null values

# %%
## train_df = train_df.dropna(subset=['fare'])
train_df['fare'].fillna(0,inplace=True)
test_df['fare'].fillna(0,inplace=True)
train_df['additional_fare'].fillna(0,inplace=True)
test_df['additional_fare'].fillna(0,inplace=True)

train_df.isna().sum()
# Out:
# tripid                         0
# additional_fare                0
# duration                     202
# meter_waiting                202
# meter_waiting_fare           202
# meter_waiting_till_pickup    202
# pickup_time                    0
# drop_time                      0
# pick_lat                       0
# pick_lon                       0
# drop_lat                       0
# drop_lon                       0
# fare                           0
# label                          0
# dtype: int64

# %% [markdown]
# encode label and create feature set

# %%
train_df['label'] = train_df['label'].apply(encoding_label).values
features_df = train_df.loc[:, train_df.columns != 'label']
label_df = train_df['label']

# %% [markdown]
# remove unnecessary columns

# %%
features_df = features_df.loc[:, features_df.columns != 'tripid']
test_df = test_df.loc[:, test_df.columns != 'tripid']

# %% [markdown]
# add some columns to dataset

# %%
features_df['fare_per_min'] = features_df.apply(lambda x:get_fare_per_min(x),axis=1 )
test_df['fare_per_min'] = test_df.apply(lambda x:get_fare_per_min(x),axis=1 )

features_df['distance'] = features_df.apply(lambda x:get_distance(x), axis=1)
test_df['distance'] = test_df.apply(lambda x:get_distance(x), axis=1)

features_df['fare_per_distance'] = features_df.apply(lambda x:get_fare_per_distance(x),axis=1 )
test_df['fare_per_distance'] = test_df.apply(lambda x:get_fare_per_distance(x),axis=1 )


## features_df['duration'] = features_df.apply(lambda x:get_duration(x),axis=1 )
## test_df['duration'] = test_df.apply(lambda x:get_duration(x),axis=1 )

features_df = features_df.drop(labels=['drop_lat','drop_lon','pickup_time','pick_lat','pick_lon','drop_time'],axis=1)
test_df = test_df.drop(labels=['drop_lat','drop_lon','pickup_time','pick_lat','pick_lon','drop_time'],axis=1)

features_df.to_csv("/content/drive/My Drive/Colab Notebooks/FAIR_TAXI/features_df.csv", index=True)

# %% [markdown]
# split train and test data

# %%
X_train, X_test, y_train, y_test = train_test_split(features_df, label_df, test_size=0.3, random_state=1)

# %% [markdown]
# ## Model Pipelines

# %%
numeric_preprocessing_steps = Pipeline([
    ('standard_scaler', StandardScaler()),
    ('simple_imputer', SimpleImputer(strategy='mean'))
])

numeric_cols = features_df.columns[features_df.dtypes != "object"].values

preprocessor = ColumnTransformer(
    transformers = [
        ("numeric", numeric_preprocessing_steps, numeric_cols)
    ],
    remainder = "drop"
)
print(numeric_cols)
# Out:
# ['additional_fare' 'duration' 'meter_waiting' 'meter_waiting_fare'
#  'meter_waiting_till_pickup' 'fare' 'fare_per_min' 'distance'
#  'fare_per_distance']

# %% [markdown]
# create random grid search cv for random forest

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestClassifier(random_state = 42)


# # Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 20)]
# # Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 15)]
max_depth.append(None)
# # Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 20]
# # Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4 , 10,20]
# # Method of selecting samples for training each tree
bootstrap = [True, False]

random_grid = {
               'esti__n_estimators': n_estimators,
               'esti__max_features': max_features,
               'esti__max_depth': max_depth,
               'esti__min_samples_split': min_samples_split,
               'esti__min_samples_leaf': min_samples_leaf,
               'esti__bootstrap': bootstrap
               }
random_grid_xgb = {
              'esti__gamma':[i/10.0 for i in range(0,5)],
              'esti__max_depth':range(3,10,2),
              'esti__min_child_weight':range(1,6,2)
}

mlp_params = {
    'esti__hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'esti__activation': ['tanh', 'relu','logistic'],
    'esti__solver': ['sgd', 'adam'],
    'esti__alpha': [0.0001, 0.05, 0.1, 0.01, 0.205, 0.0005, 0.001, 0.15],
    'esti__learning_rate': ['constant','adaptive'],
}

# %% [markdown]
# RF: 0.975229 (0.001923) - RF (with pca)  \
# RF: 0.974956 (0.001902)- BOOSt (without pca)

# %%
pca = PCA()

neural = MLPClassifier(random_state=1)

estimators = RandomForestClassifier(
      # bootstrap= False,
      # criterion="entropy",
      random_state = 1,
      max_depth=74,
      # max_features= 'sqrt',
      # min_samples_leaf= 4,
      # min_samples_split=5,
      n_estimators = 673
)

full_pipeline = Pipeline([
                          ("preprocessor", preprocessor),
                          # ("debuffe",debugerr()),
                          ("pca",pca),
                          ("esti", neural)
                          ])

# %%
# kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
# cv_results = cross_val_score(full_pipeline, features_df, label_df, cv=kfold, scoring='f1')
# print('%s: %f (%f)' % ("RF", cv_results.mean(), cv_results.std()))
# Out:
# RF: 0.973207 (0.002197)

# %%
rf_random_pipe = RandomizedSearchCV(full_pipeline, param_distributions = mlp_params, cv = 10, verbose=2, random_state=42, scoring ='f1')
rf_random_pipe.fit(features_df,label_df)
kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
cv_results = cross_val_score(rf_random_pipe, features_df, label_df, cv=kfold, scoring='f1')
print('%s: %f (%f)' % ("RF", cv_results.mean(), cv_results.std()))
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  25.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   25.1s remaining:    0.0s
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  24.5s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  24.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  24.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  24.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  24.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  24.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  24.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  25.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  24.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  31.7s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  28.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  32.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  32.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  21.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  32.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  32.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  27.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  18.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  26.6s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.8s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.8s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.8s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.7s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.7s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.7s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.5s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.5s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.5s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.5s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  52.8s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  51.8s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  51.5s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  51.3s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  51.3s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  51.3s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  51.5s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  51.5s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  52.7s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  51.4s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  17.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  18.4s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  16.4s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  12.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  18.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  18.5s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  13.7s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  27.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  15.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  13.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  25.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  24.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  24.7s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  25.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  24.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  24.7s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  24.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  24.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  25.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  24.7s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  17.9s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  19.3s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  19.1s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  17.8s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  17.4s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  18.0s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  18.5s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  18.5s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  12.8s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  19.0s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  37.6s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  36.8s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  36.2s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  36.7s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  37.0s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  36.4s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  36.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  36.6s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  37.2s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=relu, total=  37.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total= 1.0min
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total= 1.0min
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total= 1.0min
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total= 1.0min
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total=  59.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total=  59.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total=  60.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total= 1.0min
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total= 1.0min
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.001, esti__activation=tanh, total=  59.5s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  38.7s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  38.7s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  38.7s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  38.9s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  38.6s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  37.6s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  38.9s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  36.9s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  38.7s
# [CV] esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic
# [CV]  esti__solver=adam, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0001, esti__activation=logistic, total=  38.6s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed: 50.6min finished
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  22.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   22.6s remaining:    0.0s
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  22.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  21.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  22.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  22.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  21.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  21.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  21.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  22.5s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  21.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  28.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  12.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  25.5s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  27.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  27.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  28.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  23.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  28.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  14.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  15.0s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.4s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.4s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.4s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.4s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.4s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.4s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.5s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.4s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.4s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.4s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  48.2s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  46.3s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  46.2s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  46.5s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  46.1s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  46.2s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  45.9s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  46.1s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  47.4s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  46.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  12.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=   9.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  15.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  10.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  12.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  18.7s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  16.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  12.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  14.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  14.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.4s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.3s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  18.0s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  19.4s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  18.2s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  19.5s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  17.7s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  18.6s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  17.1s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  17.8s
# ...
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  21.5s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  21.4s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  21.5s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  22.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  21.5s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  24.7s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  27.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  27.5s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  18.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  24.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  24.7s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  27.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  22.7s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  20.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.0005, esti__activation=relu, total=  27.1s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic
# [CV]  esti__solver=sgd, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.0005, esti__activation=logistic, total=   3.3s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  46.0s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  44.9s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  51.2s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  44.6s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  44.3s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  44.4s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  44.2s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  44.2s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  45.4s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(50, 100, 50), esti__alpha=0.01, esti__activation=tanh, total=  44.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  15.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  12.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  12.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  17.4s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  13.2s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  13.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  14.4s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  18.1s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  17.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(50, 50, 50), esti__alpha=0.15, esti__activation=relu, total=  18.6s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.3s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  21.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  21.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  21.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.0s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  21.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  21.8s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  22.9s
# [CV] esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh
# [CV]  esti__solver=adam, esti__learning_rate=constant, esti__hidden_layer_sizes=(100,), esti__alpha=0.0001, esti__activation=tanh, total=  21.9s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh
# [CV]  esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh, total=  17.2s
# [CV] esti__solver=sgd, esti__learning_rate=adaptive, esti__hidden_layer_sizes=(100,), esti__alpha=0.01, esti__activation=tanh

# %%
# full_pipeline.fit(X_train,y_train)
# predicted = full_pipeline.predict(test_df)
# data_dict = { 'tripid':trip_id, 'prediction':predicted}
# pd_test_result = pd.DataFrame(data=data_dict)
# pd_test_result[['tripid','prediction']].to_csv("/content/drive/My Drive/Colab Notebooks/FAIR_TAXI/result.csv", index=True)

# %%
rf_random_pipe.best_params_
